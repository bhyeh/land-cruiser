# %%
import pandas as pd
import numpy as np

# %%
landcruisers = pd.read_csv('landcruisers.csv')
landcruisers.head()
# Out:
#                                        title   price  sell_date no_views  \
# 0              1987 Toyota Land Cruiser FJ60  19,000  3/22/2022    9,610
# 1      1987 Toyota Land Cruiser FJ60 4-Speed  50,750  3/19/2022    7,159
# 2              1989 Toyota Land Cruiser FJ62  22,500  3/19/2022    8,939
# 3  No Reserve: 1988 Toyota Land Cruiser FJ62  13,250  3/16/2022    9,130
# 4  No Reserve: 1984 Toyota Land Cruiser FJ60  33,000  3/14/2022    9,150
#
#   no_watchers  no_comments  no_bids                 seller_state  year series  \
# 0         685           24       22       augusta, georgia 30909  1987   fj60
# 1         544           46       35       elma, washington 98541  1987   fj60
# 2         625           39       23       orlando, florida 32827  1989   fj62
# 3         635           17       44  hyattsville, maryland 20781  1988   fj62
# 4         580           36       15   corrales, new mexico 87048  1984   fj60
#
# ...

# %%
landcruisers.isna().sum()
# Out:
# title             0
# price             0
# sell_date         0
# no_views          0
# no_watchers       0
# no_comments       0
# no_bids           0
# seller_state      0
# year              0
# series            4
# miles             3
# engine            2
# trans             3
# exterior         61
# interior        144
# misc              0
# url               0
# dtype: int64
