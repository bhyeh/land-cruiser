# %%
import pandas as pd
import numpy as np

# %%
lc = pd.read_csv('land_cruiser_scrape.csv')
lc
# Out:
#                                       title   price  sell_date no_views  \
# 0                                       NaN     NaN        NaN      NaN
# 1     1987 Toyota Land Cruiser FJ60 4-Speed  50,750  3/19/2022    7,020
# 2                                       NaN     NaN        NaN      NaN
# 3             1989 Toyota Land Cruiser FJ62  22,500  3/19/2022    8,826
# 4                                       NaN     NaN        NaN      NaN
# ..                                      ...     ...        ...      ...
# 757           1987 Toyota Land Cruiser FJ60  36,250   5/4/2017   24,773
# 758                                     NaN     NaN        NaN      NaN
# 759  27K-Mile 1989 Toyota Land Cruiser FJ62  55,000  4/20/2017   43,430
# 760                                     NaN     NaN        NaN      NaN
# 761           1986 Toyota Land Cruiser FJ60  15,750   4/5/2017   16,559
#
#     no_watchers  no_comments  no_bids               seller_state  year series  \
# ...
